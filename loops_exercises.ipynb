# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinaTrigilia/python-exercises/blob/main/loops_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Esercizi con i Cicli

# %% [markdown]
# ## 1. Potenze [[Esercizio su HackerRank](https://www.hackerrank.com/challenges/python-loops/problem)]
#
# Leggi un intero *N* compreso tra 1 e 20 in input. Per tutti gli interi non negativi *i*<N stampa i^2.

# %%
n = int(input("Immetti un valore intero tra 1 e 20 "))
for i in range(n):
  if i >=0:
    print(f"Potenza di {i} è: ", i**2)
# Out:
# Immetti un valore intero tra 1 e 20 3
# Potenza di 0 è:  0
# Potenza di 1 è:  1
# Potenza di 2 è:  4

# %% [markdown]
# ## 2. Secondo Arrivato [[Esercizio su HackerRank](https://www.hackerrank.com/challenges/find-second-maximum-number-in-a-list/problem)]
# Ricevi in input una lista con i punteggi dei partecipanti alla Giornata dello Sport Universitaria, trova il punteggio del secondo classificato.

# %%
score_list = map(int,input("Immetti la lista dei punteggi dei partecipanti alla Giornata dello Sport Universitaria ").split())
best_score = 0
second_score = 0
for i in score_list:
  if i > best_score:
    second_score = best_score
    best_score = i
  elif i > second_score:
    second_score = i
print(f"Il punteggio del secondo classificato è {second_score}")
# Out:
# Immetti la lista dei punteggi dei partecipanti alla Giornata dello Sport Universitaria 10 11 15 13
# Il punteggio del secondo classificato è 13

# %% [markdown]
# ## 3. Registro [[Esercizio su HackerRank](https://www.hackerrank.com/challenges/finding-the-percentage/problem)]
# Hai a disposizione un record di *N* studenti. Ogni record contiene il nome dello studente e il suo voto in Matematica, Fisica e Chimica. I voti possono essere numeri con la virgola. Un utente inserisci un intero *N* seguito da il nome e i voti di N studenti. Il programma deve salvare i record in un dizionario. Allla fine l'utente inserirà il nome di uno studente, il programma dovrà dare il output la media dei voti di tale studiente arrotandata a due cifre dopo la virgola.
# <br><br>
# **ESEMPIO DI INPUT**
# <br>
# 3<br>
# Krishna 67 68 69<br>
# Arjun 70 98 63<br>
# Malika 52 56 60<br>
# Malika<br>
# <br><br>
# **ESEMPIO DI OUTPUT**
# <br>
# 56.00

# %%
N = int(input("Immetti un valore intero "))
score_dic = {}
for i in range(N):
  l = (input(f"Immetti il nome dello studente {i+1} e la lista dei sui voti in Matematica, Fisica e Chimica. ").split())
  k_name = l[0]
  v_scores = list(map(float, l[1:]))
  score_dic[k_name] = v_scores

student = input("Immetti il nome di uno studente ")
if student in score_dic:
  avg = sum(score_dic[student])/len(score_dic[student])
  print(f"La media di {student} è %.2{avg}")
else:
  print("Lo studente immesso non esiste nello storico")
# Out:
# Immetti un valore intero 3
# Immetti il nome dello studente 1 e la lista dei sui voti in Matematica, Fisica e Chimica.  Malika 52 56 60.6
# Immetti il nome dello studente 2 e la lista dei sui voti in Matematica, Fisica e Chimica. Arjun 70 98 63
# Immetti il nome dello studente 3 e la lista dei sui voti in Matematica, Fisica e Chimica. Krishna 67 68 69
# Immetti il nome di uno studente Malika
# La media di Malika è %.256.199999999999996

# %% [markdown]
# ## 4. Palindromi
# Leggi una stringa in input all'interno di un loop. Se la stringa è uguale a "stop" interrompi il programma, altrimenti verifica se la stringa è un palindromo, in caso positivo stampa "PAROLA è un palidromo" inserendo la parola inserita in input al posto di PAROLA, altrimenti stampa " PAROLA non è un palindromo".
# <br><br>
# **N.B** Un palindromo è una parola che può essere letta allo stesso modo in entrambi i sensi (es. radar, osso, aerea).

# %%
word = None

while(True):

  word = input()

  if(word=="stop"):
    break

  word_len = len(word)
  is_palindrome = True

  for i in range(word_len):
    j = word_len-i-1
    if(word[i]!=word[j]):
      is_palindrome = False
      break

  if(is_palindrome):
    print("%s è un palindromo" % word)
  else:
    print("%s non è un palindromo" % word)
# Out:
# ciao
# ciao non è un palindromo
# acca
# acca è un palindromo
# asta
# asta non è un palindromo
# sos
# sos è un palindromo
# stop
